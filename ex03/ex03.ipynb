# %%
library("ggplot2")
library("tidyr")

# %%
df <- read.table(
  "GENDER_EMP_19032023152556091.txt", sep = "\t", header = FALSE,
  comment.char = "#", na.strings = c(""," ", NA),
  stringsAsFactors = FALSE, quote = "", fill = FALSE, skip = 1
)
names(df) <- c("COU", "Country", "IND", "Indicator", "SEX", "Sex",
  "AGE", "Age Group", "TIME", "Time", "Unit Code", "Unit", "PowerCode Code",
  "PowerCode", "Reference Period Code", "Reference Period", "Value", "Flag Codes", "Flags"
)
df
# Out:
#       COU  Country        IND
# 1     AUS  Australia      EMP6
# 2     AUS  Australia      EMP6
# 3     AUS  Australia      EMP6
# 4     AUS  Australia      EMP6
# 5     AUS  Australia      EMP6
# 6     AUS  Australia      EMP6
# 7     AUT  Austria        EMP6
# 8     AUT  Austria        EMP6
# 9     AUT  Austria        EMP6
# 10    AUT  Austria        EMP6
# 11    AUT  Austria        EMP6
# 12    AUT  Austria        EMP6
# 13    AUT  Austria        EMP6
# 14    AUT  Austria        EMP6
# 15    AUT  Austria        EMP6
# 16    AUT  Austria        EMP6
# 17    AUT  Austria        EMP6
# 18    AUT  Austria        EMP6
# 19    BEL  Belgium        EMP6
# 20    BEL  Belgium        EMP6
# 21    BEL  Belgium        EMP6
# 22    BEL  Belgium        EMP6
# 23    BEL  Belgium        EMP6
# 24    BEL  Belgium        EMP6
# 25    BEL  Belgium        EMP6
# 26    BEL  Belgium        EMP6
# 27    BEL  Belgium        EMP6
# 28    BEL  Belgium        EMP6
# 29    BEL  Belgium        EMP6
# ...
